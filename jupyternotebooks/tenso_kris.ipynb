# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FeetCodingHommy/pypyo-friends/blob/master/jupyternotebooks/tenso_kris.ipynb)

# %% [markdown]
# # Colab에서 TensorFlow와 Keras를 써보세요

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.5.0'

# %%
from tensorflow import keras

keras.__version__
# Out:
# '2.5.0'
