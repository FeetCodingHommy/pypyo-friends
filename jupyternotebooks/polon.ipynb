# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FeetCodingHommy/pypyo-friends/blob/master/jupyternotebooks/polon.ipynb)

# %% [markdown]
# # Colab에서 Polars를 써보세요

# %%
# !pip install polars

import polars as pl

pl.__version__
# Out:
# ...
#      |████████████████████████████████| 10.4 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 21.8 MB 32.6 MB/s
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 3.0.0
#     Uninstalling pyarrow-3.0.0:
#       Successfully uninstalled pyarrow-3.0.0
# ...
# '0.8.12'
