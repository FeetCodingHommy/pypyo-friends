# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FeetCodingHommy/pypyo-friends/blob/master/jupyternotebooks/plotlyat.ipynb)

# %% [markdown]
# # Colab에서 plot.ly를 써보세요

# %%
from plotly import __version__ as plotly_version

plotly_version
# Out:
# '4.4.1'

# %%
import plotly.graph_objs as go
